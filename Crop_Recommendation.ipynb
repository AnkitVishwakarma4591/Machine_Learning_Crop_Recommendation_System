# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
crop = pd.read_csv("Crop_recommendation.csv")

# %%
crop.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
crop.shape
# Out:
# (2200, 8)

# %%
crop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
crop.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %% [markdown]
# ### Checking Outlier

# %%
for i in range(7):
    sns.distplot(crop.iloc[:,i])
    plt.show()
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_17396\1396062998.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(crop.iloc[:,i])
# C:\Users\ankit\AppData\Local\Temp\ipykernel_17396\1396062998.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(crop.iloc[:,i])
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
crop['label'] = LabelEncoder().fit_transform(crop[['label']])
# Out:
# C:\Users\ankit\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
crop['label'].value_counts()
# Out:
# label
# 0     100
# 1     100
# 2     100
# 3     100
# 4     100
# 5     100
# 6     100
# 7     100
# 8     100
# 9     100
# 10    100
# 11    100
# 12    100
# 13    100
# 14    100
# 15    100
# 16    100
# 17    100
# 18    100
# 19    100
# 20    100
# 21    100
# Name: count, dtype: int64

# %%
x = crop.iloc[:,:-1]
y = crop['label']

# %%
x
# Out:
#         N   P   K  temperature   humidity        ph    rainfall
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340
# ...   ...  ..  ..          ...        ...       ...         ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041
#
# [2200 rows x 7 columns]

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 2195    21
# 2196    21
# 2197    21
# 2198    21
# 2199    21
# Name: label, Length: 2200, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = pd.DataFrame(sc.fit_transform(x), columns=x.columns)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
model_RFC = RandomForestClassifier(n_estimators=200, random_state=42).fit(x_train,y_train)
model_GB = GradientBoostingClassifier(n_estimators=300, learning_rate=0.05, max_depth=6, random_state=42).fit(x_train,y_train)
model_XGB = XGBClassifier(n_estimators=250, learning_rate=0.1, max_depth=5, random_state=42).fit(x_train,y_train)

# %%
y_pred_RFC = model_RFC.predict(x_test)
y_pred_GB = model_GB.predict(x_test)
y_pred_XGB = model_XGB.predict(x_test)

# %%
acc_RFC = accuracy_score(y_test, y_pred_RFC)*100
acc_GB = accuracy_score(y_test, y_pred_GB)*100
acc_XGB = accuracy_score(y_test, y_pred_XGB)*100

# %%
print("The accuracy for RFC is: ",acc_RFC)
print("The accuracy for GB is: ",acc_GB)
print("The accuracy for XGB is: ",acc_XGB)
# Out:
# The accuracy for RFC is:  99.31818181818181
# The accuracy for GB is:  96.81818181818181
# The accuracy for XGB is:  98.63636363636363

# %%
model_RFC
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
model_GB
# Out:
# GradientBoostingClassifier(learning_rate=0.05, max_depth=6, n_estimators=300,
#                            random_state=42)

# %%
model_XGB
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=250, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
pwd
# Out:
# 'C:\\Users\\ankit\\Downloads\\Crop_Recommendation-main'

# %%
import joblib

# %%
joblib.dump(model_RFC, "Crop_Recommendation.pkl")
# Out:
# ['Crop_Recommendation.pkl']

# %%
loaded_model = joblib.load("Crop_Recommendation.pkl")
